# %%
import pandas as pd
import numpy as np
# Import matplotlib's pyplot module for creating visualizations
import matplotlib.pyplot as plt
# Import seaborn, a statistical data visualization library built on matplotlib
import seaborn as sns

# %%
# Sample data
data = {
    'Math': [78, 85, 96, 80, 86],
    'Science': [88, 90, 94, 82, 89],
    'English': [72, 75, 78, 70, 74]
}
df = pd.DataFrame(data)

# %%
# Compute the correlation matrix
correlation_matrix = df.corr()

print(correlation_matrix)
# Out:
#              Math   Science   English
# Math     1.000000  0.798978  0.918423
# Science  0.798978  1.000000  0.961873
# English  0.918423  0.961873  1.000000

# %%
plt.figure(figsize = (12, 8))
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation Matrix")
plt.show()
